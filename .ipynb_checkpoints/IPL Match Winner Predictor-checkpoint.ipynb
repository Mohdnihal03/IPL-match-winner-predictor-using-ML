# %% [markdown]
# # IPL MATCH WINNER PREDICTION
#
# ### Dataset : IPL match dataset from kaggle

# %% [markdown]
# - **LOADING THE DATASET AND KNOWING ABOUT THE DATASET**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
match = pd.read_csv("matches.csv")
delivery = pd.read_csv("deliveries.csv")
match.shape , delivery.shape
# Out:
# ((756, 18), (179078, 21))

# %%
delivery.sample(5)
# Out:
#         match_id  inning                 batting_team           bowling_team  \
# 153742      7908       1             Rajasthan Royals  Kolkata Knight Riders
# 130193       549       2             Rajasthan Royals         Mumbai Indians
# 50483        214       1  Royal Challengers Bangalore        Deccan Chargers
# 121701       513       2               Mumbai Indians       Rajasthan Royals
# 138344       585       2                Gujarat Lions         Mumbai Indians
#
#         over  ball    batsman  non_striker          bowler  is_super_over  \
# 153742     1     3    D Short    AM Rahane       PP Chawla              0
# 130193     3     4  SR Watson    AM Rahane  MJ McClenaghan              0
# 50483      6     3   R Dravid    JH Kallis        RP Singh              0
# 121701    11     4  AT Rayudu  CJ Anderson     JP Faulkner              0
# 138344     5     2   AJ Finch     SK Raina      TG Southee              0
#
# ...

# %%
match.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
total_Score_df = delivery.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_Score_df.head(5)
# Out:
#    match_id  inning  total_runs
# 0         1       1         207
# 1         1       2         172
# 2         2       1         184
# 3         2       2         187
# 4         3       1         183

# %%
total_Score_df = total_Score_df[total_Score_df['inning']==1]
total_Score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %%
match_df = match.merge(total_Score_df[['match_id','total_runs']],left_on='id',right_on='match_id')
match_df.head(6)
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5   6  IPL-2017  Hyderabad  09-04-2017                Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
#teams which is currently playing ipl
teams =[
    'Royal Challengers Bengaluru',
    'Mumbai Indians',
    'Kolkata Knight Riders',
    'Rajasthan Royals',
    'Chennai Super Kings',
    'Sunrisers Hyderabad',
    'Delhi Capitals',
    'Punjab Kings',
    'Lucknow Super Giants',
    'Gujarat Titans',
]

# %%
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['team1'] = match_df['team1'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')
match_df['team2'] = match_df['team2'].str.replace('Royal Challengers Bangalore','Royal Challengers Bengaluru')

match_df['team1'] = match_df['team1'].str.replace('Kings XI Punjab','Punjab Kings')
match_df['team2'] = match_df['team2'].str.replace('Kings XI Punjab','Punjab Kings')

# %%
match_df = match_df[match['team1'].isin(teams)]
match_df = match_df[match['team2'].isin(teams)]
# Out:
# C:\Users\nihall\AppData\Local\Temp\ipykernel_13212\1393797100.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   match_df = match_df[match['team2'].isin(teams)]

# %%
match_df
# Out:
#         id    Season           city        date                  team1  \
# 6        7  IPL-2017         Mumbai  09-04-2017  Kolkata Knight Riders
# 9       10  IPL-2017         Mumbai  12-04-2017    Sunrisers Hyderabad
# 13      14  IPL-2017        Kolkata  15-04-2017  Kolkata Knight Riders
# 35      36  IPL-2017      Hyderabad  30-04-2017    Sunrisers Hyderabad
# 46      47  IPL-2017      Hyderabad  08-05-2017         Mumbai Indians
# ..     ...       ...            ...         ...                    ...
# 751  11347  IPL-2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019         Mumbai Indians
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
match_df = match_df[['match_id','city','winner','total_runs']]
match_df
# Out:
#      match_id           city                 winner  total_runs
# 6           7         Mumbai         Mumbai Indians         178
# 9          10         Mumbai         Mumbai Indians         158
# 13         14        Kolkata  Kolkata Knight Riders         172
# 35         36      Hyderabad    Sunrisers Hyderabad         209
# 46         47      Hyderabad    Sunrisers Hyderabad         138
# ..        ...            ...                    ...         ...
# 751     11347         Mumbai         Mumbai Indians         143
# 752     11412        Chennai         Mumbai Indians         136
# 753     11413  Visakhapatnam         Delhi Capitals         171
# 754     11414  Visakhapatnam    Chennai Super Kings         155
# 755     11415      Hyderabad         Mumbai Indians         152
#
# [200 rows x 4 columns]

# %%
delivery_df = match_df.merge(delivery,on='match_id')

# %%
delivery_df = delivery_df[delivery_df['inning']==2]
delivery_df.shape
# Out:
# (23057, 24)

# %%
delivery_df
# Out:
#        match_id       city          winner  total_runs_x  inning  \
# 128           7     Mumbai  Mumbai Indians           178       2
# 129           7     Mumbai  Mumbai Indians           178       2
# 130           7     Mumbai  Mumbai Indians           178       2
# 131           7     Mumbai  Mumbai Indians           178       2
# 132           7     Mumbai  Mumbai Indians           178       2
# ...         ...        ...             ...           ...     ...
# 47839     11415  Hyderabad  Mumbai Indians           152       2
# 47840     11415  Hyderabad  Mumbai Indians           152       2
# 47841     11415  Hyderabad  Mumbai Indians           152       2
# 47842     11415  Hyderabad  Mumbai Indians           152       2
# 47843     11415  Hyderabad  Mumbai Indians           152       2
#
#               batting_team           bowling_team  over  ball    batsman  ...  \
# 128         Mumbai Indians  Kolkata Knight Riders     1     1   PA Patel  ...
# ...

# %%
delivery_df['current_score']=  delivery_df.groupby('match_id')['total_runs_y'].cumsum()
delivery_df
# Out:
#        match_id       city          winner  total_runs_x  inning  \
# 128           7     Mumbai  Mumbai Indians           178       2
# 129           7     Mumbai  Mumbai Indians           178       2
# 130           7     Mumbai  Mumbai Indians           178       2
# 131           7     Mumbai  Mumbai Indians           178       2
# 132           7     Mumbai  Mumbai Indians           178       2
# ...         ...        ...             ...           ...     ...
# 47839     11415  Hyderabad  Mumbai Indians           152       2
# 47840     11415  Hyderabad  Mumbai Indians           152       2
# 47841     11415  Hyderabad  Mumbai Indians           152       2
# 47842     11415  Hyderabad  Mumbai Indians           152       2
# 47843     11415  Hyderabad  Mumbai Indians           152       2
#
#               batting_team           bowling_team  over  ball    batsman  ...  \
# 128         Mumbai Indians  Kolkata Knight Riders     1     1   PA Patel  ...
# ...

# %%
delivery_df['runs_left'] = delivery_df['total_runs_x'] - delivery_df['current_score']
delivery_df
# Out:
#        match_id       city          winner  total_runs_x  inning  \
# 128           7     Mumbai  Mumbai Indians           178       2
# 129           7     Mumbai  Mumbai Indians           178       2
# 130           7     Mumbai  Mumbai Indians           178       2
# 131           7     Mumbai  Mumbai Indians           178       2
# 132           7     Mumbai  Mumbai Indians           178       2
# ...         ...        ...             ...           ...     ...
# 47839     11415  Hyderabad  Mumbai Indians           152       2
# 47840     11415  Hyderabad  Mumbai Indians           152       2
# 47841     11415  Hyderabad  Mumbai Indians           152       2
# 47842     11415  Hyderabad  Mumbai Indians           152       2
# 47843     11415  Hyderabad  Mumbai Indians           152       2
#
#               batting_team           bowling_team  over  ball    batsman  ...  \
# 128         Mumbai Indians  Kolkata Knight Riders     1     1   PA Patel  ...
# ...

# %%
delivery_df['balls_left']= 126 - (delivery_df['over'] * 6 + delivery_df['ball'])

# %%
delivery_df
# Out:
#        match_id       city          winner  total_runs_x  inning  \
# 128           7     Mumbai  Mumbai Indians           178       2
# 129           7     Mumbai  Mumbai Indians           178       2
# 130           7     Mumbai  Mumbai Indians           178       2
# 131           7     Mumbai  Mumbai Indians           178       2
# 132           7     Mumbai  Mumbai Indians           178       2
# ...         ...        ...             ...           ...     ...
# 47839     11415  Hyderabad  Mumbai Indians           152       2
# 47840     11415  Hyderabad  Mumbai Indians           152       2
# 47841     11415  Hyderabad  Mumbai Indians           152       2
# 47842     11415  Hyderabad  Mumbai Indians           152       2
# 47843     11415  Hyderabad  Mumbai Indians           152       2
#
#               batting_team           bowling_team  over  ball    batsman  ...  \
# 128         Mumbai Indians  Kolkata Knight Riders     1     1   PA Patel  ...
# ...

# %%
# delivery_df['player_dismissed']= delivery_df['player_dismissed'].fillna('0')
# delivery_df['player_dismissed']= delivery_df['player_dismissed'].apply(lambda x: x if x=='0'else'1')
# delivery_df['player_dismissed']= delivery_df['player_dismissed'].astype('int')
# wickets = delivery_df.groupby('match_id').cumsum()['player_dismissed'].values
# delivery_df['wickets']= 10 - wickets
# delivery_df.sample(5)

# %%
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].fillna('0')
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].apply(lambda x: '0' if x == '0' else '1')
delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype(int)

# Calculate cumulative wickets for each match
delivery_df['cumulative_wickets'] = delivery_df.groupby('match_id')['player_dismissed'].transform(pd.Series.cumsum)

# Calculate remaining wickets
delivery_df['wickets_left'] = 10 - delivery_df['cumulative_wickets']
delivery_df
# Out:
#        match_id       city          winner  total_runs_x  inning  \
# 128           7     Mumbai  Mumbai Indians           178       2
# 129           7     Mumbai  Mumbai Indians           178       2
# 130           7     Mumbai  Mumbai Indians           178       2
# 131           7     Mumbai  Mumbai Indians           178       2
# 132           7     Mumbai  Mumbai Indians           178       2
# ...         ...        ...             ...           ...     ...
# 47839     11415  Hyderabad  Mumbai Indians           152       2
# 47840     11415  Hyderabad  Mumbai Indians           152       2
# 47841     11415  Hyderabad  Mumbai Indians           152       2
# 47842     11415  Hyderabad  Mumbai Indians           152       2
# 47843     11415  Hyderabad  Mumbai Indians           152       2
#
#               batting_team           bowling_team  over  ball    batsman  ...  \
# 128         Mumbai Indians  Kolkata Knight Riders     1     1   PA Patel  ...
# ...

# %%
delivery_df.tail()
# Out:
#        match_id       city          winner  total_runs_x  inning  \
# 47839     11415  Hyderabad  Mumbai Indians           152       2
# 47840     11415  Hyderabad  Mumbai Indians           152       2
# 47841     11415  Hyderabad  Mumbai Indians           152       2
# 47842     11415  Hyderabad  Mumbai Indians           152       2
# 47843     11415  Hyderabad  Mumbai Indians           152       2
#
#               batting_team    bowling_team  over  ball    batsman  ...  \
# 47839  Chennai Super Kings  Mumbai Indians    20     2  RA Jadeja  ...
# 47840  Chennai Super Kings  Mumbai Indians    20     3  SR Watson  ...
# 47841  Chennai Super Kings  Mumbai Indians    20     4  SR Watson  ...
# 47842  Chennai Super Kings  Mumbai Indians    20     5  SN Thakur  ...
# 47843  Chennai Super Kings  Mumbai Indians    20     6  SN Thakur  ...
#
#       extra_runs total_runs_y  player_dismissed  dismissal_kind    fielder  \
# ...

# %%
### current runrate and required run rate

# %%
# crr = runs/overs
delivery_df['current_runrate']= delivery_df['current_score']*6/(120-delivery_df['balls_left'])

# %%
delivery_df.head(10)
# Out:
#      match_id    city          winner  total_runs_x  inning    batting_team  \
# 128         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 129         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 130         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 131         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 132         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 133         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 134         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 135         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 136         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 137         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
#
#               bowling_team  over  ball     batsman  ... total_runs_y  \
# ...

# %%
### required runrate 

delivery_df['required_runrate']= delivery_df['runs_left']*6/(120-delivery_df['balls_left'])
delivery_df.head()
# Out:
#      match_id    city          winner  total_runs_x  inning    batting_team  \
# 128         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 129         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 130         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 131         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
# 132         7  Mumbai  Mumbai Indians           178       2  Mumbai Indians
#
#               bowling_team  over  ball   batsman  ... player_dismissed  \
# 128  Kolkata Knight Riders     1     1  PA Patel  ...                0
# 129  Kolkata Knight Riders     1     2  PA Patel  ...                0
# 130  Kolkata Knight Riders     1     3  PA Patel  ...                0
# 131  Kolkata Knight Riders     1     4  PA Patel  ...                0
# 132  Kolkata Knight Riders     1     5  PA Patel  ...                0
#
#     dismissal_kind  fielder  current_score  runs_left  balls_left  \
# ...

# %%
def result(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result,axis=1)

# %%
final_df = delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','current_runrate','required_runrate','result']]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#               batting_team           bowling_team     city  runs_left  \
# 20265       Mumbai Indians    Sunrisers Hyderabad   Mumbai        174
# 35067  Sunrisers Hyderabad  Kolkata Knight Riders  Kolkata         27
#
#        balls_left  wickets_left  current_runrate  required_runrate  result
# 20265         115            10         4.800000        208.800000       1
# 35067          25             6         7.452632          1.705263       1

# %%
final_df.dropna(inplace=True)

# %%
x = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((18154, 8), (4539, 8), (18154,), (4539,))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf1 = ColumnTransformer([
    ('Ohe',OneHotEncoder(sparse=False, drop='first'),['batting_team','bowling_team','city'])
],remainder='passthrough')

# %%
trf1
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('Ohe',
#                                  OneHotEncoder(drop='first', sparse=False),
#                                  ['batting_team', 'bowling_team', 'city'])])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf1),
    ('step2',LogisticRegression(solver='liblinear'))
    
])

# %%
pipe
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
x_train.describe()
# Out:
#           runs_left    balls_left  wickets_left  current_runrate  \
# count  18154.000000  18154.000000  18154.000000     18154.000000
# mean      90.846921     62.763688      7.631596         7.445249
# std       48.686403     33.437532      2.148794         2.248703
# min       -8.000000     -2.000000      0.000000         0.000000
# 25%       53.000000     35.000000      6.000000         6.285714
# 50%       91.000000     64.000000      8.000000         7.500000
# 75%      127.000000     92.000000      9.000000         8.636151
# max      246.000000    119.000000     10.000000        42.000000
#
#        required_runrate
# count      18154.000000
# mean          38.699041
# std          110.128604
# min           -0.448598
# 25%            3.750000
# 50%            9.684211
# 75%           26.608696
# max         1476.000000

# %%
pipe.fit(x_train,y_train)
# Out:
# C:\Users\nihall\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Ohe',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8396122493941397

# %%
pipe.predict_proba(x_test)[10]
# Out:
# array([0.63855743, 0.36144257])

# %% [markdown]
# ### EDA

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18154 entries, 7828 to 3377
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   batting_team      18154 non-null  object
#  1   bowling_team      18154 non-null  object
#  2   city              18154 non-null  object
#  3   runs_left         18154 non-null  int64
#  4   balls_left        18154 non-null  int64
#  5   wickets_left      18154 non-null  int32
#  6   current_runrate   18154 non-null  float64
#  7   required_runrate  18154 non-null  float64
# dtypes: float64(2), int32(1), int64(2), object(3)
# memory usage: 1.2+ MB

# %%
plt.scatter(x)
